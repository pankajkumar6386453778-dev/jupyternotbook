# %%
# !pip install requests

# %%
import requests

# %%
URL= "https://stephen-king-api.onrender.com/api/books"

json_data =  requests.get(URL)

# %%
json_data = res.json()

# %%
import pandas as pd

df = pd.json_normalize(json_data["data"])
df = df[['id','Title','Year','ISBN']]

# %%
df
# Out:
#     id            Title  Year                  ISBN
# 0    1           Carrie  1974     978-0-385-08695-0
# 1    2      Salem's Lot  1975     978-0-385-00751-1
# 2    3      The Shining  1977     978-0-385-12167-5
# 3    4             Rage  1977     978-0-451-07645-8
# 4    5        The Stand  1978     978-0-385-12168-2
# ..  ..              ...   ...                   ...
# 59  60        Elevation  2018     978-1-98210-231-9
# 60  61    The Institute  2019     978-1-98211-056-7
# 61  62            Later  2021     978-1-78909-649-1
# 62  63    Billy Summers  2021     978-1-982-17361-6
# 63  72  The Roopak Zone  1979  978-0-670-26069697-5
#
# [64 rows x 4 columns]

# %%
#Web Scrapping
import requests
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

print(res.status_code)
# Out:
# 200

# %%
res
# Out:
# <Response [200]>

# %%
if res.status_code ==200:
    print(res.headers)

with open("scraped_data/data1.html","w") as f:
    f.write(res.text)
# Out:
# {'Date': 'Sat, 04 Jul 2026 05:52:15 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=jJzwNao9eA%2Bg52JtfZmwXU6ogWK%2BDrYMQ8XBWtJOXBc%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1783144335"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=jJzwNao9eA%2Bg52JtfZmwXU6ogWK%2BDrYMQ8XBWtJOXBc%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1783144335"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'Cf-Cache-Status': 'DYNAMIC', 'Content-Encoding': 'br', 'CF-RAY': 'a15bdcdeff81b21e-DEL', 'alt-svc': 'h3=":443"; ma=86400'}
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[16], line 5
#       1 if res.status_code ==200:
#       2     print(res.headers)
#       3
#       4 with open("scraped_data/data1.html","w") as f:
# ----> 5     f.write(res.text)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u015f' in position 115200: character maps to <undefined>

# %%
#beautiful soup
from bs4 import BeautifulSoup

with open("scraped_data/data1.html","r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content,"lxml")

# %%
soup

# %%
all_h3 = soup.find_all("h3")
for h3 in all_h3:
    name = (h3.get_text(strip=True))
    print(h3.find_parent("div")["class"])
