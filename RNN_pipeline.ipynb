# %%
#pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformer chromodg

# %%
from  langchain_core.documents import Document

# %%
#self data document created
sample_doc = Document(
    page_content = "Hello world!",
    metadata = {"source":"http:/www.google.com"}
)

# %%
sample_doc
# Out:
# Document(metadata={'source': 'http:/www.google.com'}, page_content='Hwllo world!')

# %%
type(sample_doc)
# Out:
# langchain_core.documents.base.Document

# %%
#Text data
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader("data/Python.txt" , encoding="utf-8")
# Out:
# C:\Users\panka\AppData\Local\Temp\ipykernel_22788\350610897.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders.text import TextLoader
